# %%
# Importing necessary packages
import numpy as np 
import pandas as pd
import os
import warnings

warnings.filterwarnings('ignore')

# %%
# Define the source and destination root folders (relative to this script)
source_root = '../data'
destination_root = '../Preprocessed_Data'

# Define the three categories
categories = ['Large_Cap', 'Mid_Cap', 'Small_Cap']

for category in categories:
    source_path = os.path.join(source_root, category)
    destination_path = os.path.join(destination_root, category)

    # Check if the source path exists before proceeding
    if not os.path.exists(source_path):
        print(f"Source folder not found: {source_path}")
        continue

    # Create destination directory if it doesn't exist
    os.makedirs(destination_path, exist_ok=True)

    # Loop through all CSV files in the source category folder
    for file_name in os.listdir(source_path):
        if file_name.endswith('.csv'):
            full_file_path = os.path.join(source_path, file_name)

            # Read the CSV file
            df = pd.read_csv(full_file_path)

            # Filter rows where Series column is 'EQ'
            if 'Series' in df.columns:
                df = df[df.Series == 'EQ']

            # Drop missing values
            df.dropna(inplace=True)

            # Save the preprocessed file
            output_file_path = os.path.join(destination_path, file_name)
            df.to_csv(output_file_path, index=False)

            print(f"Processed and saved: {output_file_path}")
# Out:
# Processed and saved: ../Preprocessed_Data\Large_Cap\ADANIPORTS.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\ASIANPAINT.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\AXISBANK.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\BAJFINANCE.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\BPCL.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\CIPLA.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\DRREDDY.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\EICHERMOT.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\GAIL.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\HDFC.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\HDFCBANK.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\HEROMOTOCO.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\HINDALCO.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\HINDUNILVR.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\INFRATEL.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\INFY.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\IOC.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\ITC.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\LT.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\M&M.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\MARUTI.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\RELIANCE.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\SUNPHARMA.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\TCS.csv
# Processed and saved: ../Preprocessed_Data\Large_Cap\TITAN.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\ADANIPOWER.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\AJANTPHARM.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\AMARAJABAT.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\APOLLOTYRE.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\BERGEPAINT.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\CASTROLIND.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\CUMMINSIND.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\DHFL.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\EXIDEIND.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\GMRINFRA.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\GODREJIND.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\IDBI.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\IGL.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\JINDALSTEL.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\JUBLFOOD.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\MINDTREE.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\MRPL.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\MUTHOOTFIN.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\NBCC.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\PNB.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\RBLBANK.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\RELINFRA.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\SUNTV.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\TATACHEM.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\TATAPOWER.csv
# Processed and saved: ../Preprocessed_Data\Mid_Cap\VOLTAS.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\ASHOKA.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\BAJAJELEC.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\BOMDYEING.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\CENTURYPLY.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\FORTIS.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\GUJALKALI.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\IDFC.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\IRCON.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\ITDC.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\JETAIRWAYS.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\JKLAKSHMI.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\LALPATHLAB.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\LAXMIMACH.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\LEMONTREE.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\LUXIND.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\MINDAIND.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\NCC.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\PVR.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\RAYMOND.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\RCOM.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\SONATSOFTW.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\SUZLON.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\VENKEYS.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\VIPIND.csv
# Processed and saved: ../Preprocessed_Data\Small_Cap\WELSPUNIND.csv
